# %% [markdown]
# ### Video Game Sales

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.plotting.register_matplotlib_converters()
print("Setup done")
# Out:
# Setup done

# %% [markdown]
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
# Fields include
#
# Rank - Ranking of overall sales
#
# Name - The games name
#
# Platform - Platform of the games release (i.e. PC,PS4, etc.)
#
# Year - Year of the game's release
#
# Genre - Genre of the game
#
# Publisher - Publisher of the game
#
# NA_Sales - Sales in North America (in millions)
#
# EU_Sales - Sales in Europe (in millions)
#
# JP_Sales - Sales in Japan (in millions)
#
# Other_Sales - Sales in the rest of the world (in millions)
#
# Global_Sales - Total worldwide sales.

# %%
vg_data = pd.read_csv("C:/Users/chaur/Desktop/Data Analysis/Datasets/vgsales.csv")

# %%
vg_data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vg_data.corr()
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.178814 -0.401362 -0.379123 -0.267785    -0.332986
# Year          0.178814  1.000000 -0.091402  0.006014 -0.169316     0.041058
# NA_Sales     -0.401362 -0.091402  1.000000  0.767727  0.449787     0.634737
# EU_Sales     -0.379123  0.006014  0.767727  1.000000  0.435584     0.726385
# JP_Sales     -0.267785 -0.169316  0.449787  0.435584  1.000000     0.290186
# Other_Sales  -0.332986  0.041058  0.634737  0.726385  0.290186     1.000000
# Global_Sales -0.427407 -0.074735  0.941047  0.902836  0.611816     0.748331
#
#               Global_Sales
# Rank             -0.427407
# Year             -0.074735
# NA_Sales          0.941047
# EU_Sales          0.902836
# JP_Sales          0.611816
# Other_Sales       0.748331
# Global_Sales      1.000000

# %%
vg_data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
sns.heatmap(vg_data.corr())

# %%
vg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
vg_data.shape
# Out:
# (16598, 11)

# %%
vg_data.dropna(how= 'any', inplace= True)

# %%
vg_data['Genre'].value_counts().head(10)
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Name: Genre, dtype: int64

# %%
vg_data['Genre'].value_counts().plot(kind = "bar")

# %%
vg_data['Year'].value_counts().head(10)
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# Name: Year, dtype: int64

# %%
plt.figure(figsize = (10,8))
vg_data['Year'].value_counts().plot(kind = "bar")

# %%
vg_data['Publisher'].value_counts().head(10)
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# THQ                              712
# Nintendo                         696
# Sony Computer Entertainment      682
# Sega                             632
# Take-Two Interactive             412
# Name: Publisher, dtype: int64

# %%
vg_data['Platform'].value_counts().head(10)
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# Name: Platform, dtype: int64

# %%
vg_data['Platform'].value_counts().plot(kind= "bar")

# %%
df = pd.DataFrame(vg_data)

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df["NA_Sales"] [df["Genre"]=="Racing"].count()
# Out:
# 1225

# %%
vg_data["Name"].value_counts().sort_values(ascending= False).head(10)
# Out:
# Need for Speed: Most Wanted    12
# Ratatouille                     9
# FIFA 14                         9
# LEGO Marvel Super Heroes        9
# LEGO The Hobbit                 8
# Angry Birds Star Wars           8
# Madden NFL 07                   8
# Cars                            8
# FIFA 15                         8
# Madden NFL 08                   8
# Name: Name, dtype: int64

# %%
vg_data["Name"].value_counts().head(15).plot(kind = "bar")

# %% [markdown]
# North America Sales

# %%
na_sales = vg_data[vg_data.columns[1:7]]
#na_sales = vg_data[["Rank", "Name","Platform","Year","Genre","Publisher","NA_Sales"]]

# %%
na_sales.head()
# Out:
#                        Name Platform    Year         Genre Publisher  NA_Sales
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo     11.27

# %%
na_sales["Name"].value_counts().head(10).plot(kind= "bar")

# %%
na_sales_new = vg_data[vg_data.columns[1:7]]
na_sales_new.head()
# Out:
#                        Name Platform    Year         Genre Publisher  NA_Sales
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo     11.27

# %%
df.groupby('Platform')['NA_Sales'].sum()
# Out:
# Platform
# 2600     80.78
# 3DO       0.00
# 3DS      78.03
# DC        5.43
# DS      388.53
# GB      113.64
# GBA     178.43
# GC      131.94
# GEN      19.27
# GG        0.00
# N64     138.91
# NES     125.94
# NG        0.00
# PC       92.04
# PCFX      0.00
# PS      334.71
# PS2     572.92
# PS3     388.90
# PS4      96.80
# PSP     107.09
# PSV      16.07
# SAT       0.72
# SCD       1.00
# SNES     61.23
# TG16      0.00
# WS        0.00
# Wii     497.37
# WiiU     38.32
# X360    594.33
# XB      182.06
# XOne     83.19
# Name: NA_Sales, dtype: float64

# %%
df.groupby('Platform')['NA_Sales'].sum().plot(kind='bar')

# %%
df.groupby('Name')['NA_Sales'].sum().sort_values(ascending= False)
# Out:
# Name
# Wii Sports                                         41.49
# Super Mario Bros.                                  32.48
# Duck Hunt                                          26.93
# Tetris                                             26.17
# Grand Theft Auto V                                 23.46
#                                                    ...
# StarCraft                                           0.00
# StarBlade α                                         0.00
# Star Wars: Empire at War - Forces of Corruption     0.00
# Star Trek: Legacy                                   0.00
# ¡Shin Chan Flipa en colores!                        0.00
# Name: NA_Sales, Length: 11325, dtype: float64

# %%
plt.figure(figsize=(10,10))
df.groupby('Publisher')['NA_Sales'].sum()
# Out:
# Publisher
# 10TACLE Studios                 0.07
# 1C Company                      0.01
# 20th Century Fox Video Games    1.82
# 2D Boy                          0.00
# 3DO                             6.48
#                                 ...
# id Software                     0.02
# imageepoch Inc.                 0.00
# inXile Entertainment            0.02
# mixi, Inc                       0.00
# responDESIGN                    0.09
# Name: NA_Sales, Length: 576, dtype: float64

# %%
df.groupby('Publisher')['NA_Sales'].sum().sort_values(ascending= False).head(10)
# Out:
# Publisher
# Nintendo                       815.75
# Electronic Arts                584.22
# Activision                     426.01
# Sony Computer Entertainment    265.22
# Ubisoft                        252.81
# Take-Two Interactive           220.47
# THQ                            208.60
# Microsoft Game Studios         155.35
# Sega                           108.78
# Atari                          101.23
# Name: NA_Sales, dtype: float64

# %%
df.groupby('Publisher')['NA_Sales'].sum().sort_values(ascending= False).head(10).plot(kind= 'bar')

# %%
df.groupby('Name')['NA_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Wii Sports                        41.49
# Super Mario Bros.                 32.48
# Duck Hunt                         26.93
# Tetris                            26.17
# Grand Theft Auto V                23.46
# Call of Duty: Black Ops           17.01
# Super Mario World                 15.99
# Mario Kart Wii                    15.85
# Wii Sports Resort                 15.75
# Call of Duty: Modern Warfare 3    15.58
# Name: NA_Sales, dtype: float64

# %%
df.groupby('Name')['NA_Sales'].sum().sort_values(ascending=False).head(10).plot(kind= 'bar')

# %%
df.groupby('Genre')['NA_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Genre
# Action          861.77
# Sports          670.09
# Shooter         575.16
# Platform        445.99
# Misc            396.92
# Racing          356.93
# Role-Playing    326.50
# Fighting        220.74
# Simulation      181.78
# Puzzle          122.01
# Name: NA_Sales, dtype: float64

# %%
df.groupby('Genre')['NA_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Platform')['NA_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Platform
# X360    594.33
# PS2     572.92
# Wii     497.37
# PS3     388.90
# DS      388.53
# PS      334.71
# XB      182.06
# GBA     178.43
# N64     138.91
# GC      131.94
# Name: NA_Sales, dtype: float64

# %%
plt.figure(figsize=(10,6))
df.groupby('Year')['NA_Sales'].sum().sort_values(ascending = False).plot(kind='bar')

# %%
y = na_sales.groupby(['Year'])['NA_Sales'].size()
x = y.index.astype(int)
plt.figure(figsize=(10,6))
plt.xticks(fontsize=12, rotation=90)
ax=sns.barplot(y = y, x = x)

# %%
y = na_sales.groupby(['Platform'])['Genre'].size()
x = y.index.astype(str)
plt.figure(figsize=(10,6))
plt.xticks(fontsize=12, rotation=90)
ax=sns.barplot(y = y, x = x)

# %%
vg_data.groupby(["Genre","Publisher"])["NA_Sales"].count()
# Out:
# Genre     Publisher
# Action    20th Century Fox Video Games               4
#           3DO                                       17
#           505 Games                                 21
#           5pb                                        5
#           989 Studios                                2
#                                                     ..
# Strategy  Vivendi Games                             12
#           Warner Bros. Interactive Entertainment     2
#           Westwood Studios                           1
#           Zoo Digital Publishing                     1
#           Zushi Games                                2
# Name: NA_Sales, Length: 1823, dtype: int64

# %%
y = na_sales.groupby(['Year'])['Platform'].size()
x = y.index.astype(str)
plt.figure(figsize=(10,6))
plt.xticks(fontsize=12, rotation=90)
ax=sns.barplot(y = y, x = x)

# %% [markdown]
# ###EU Sales

# %%
eu_sales = vg_data[["Rank", "Name","Platform","Year","Genre","Publisher","EU_Sales"]]

# %%
eu_sales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    EU_Sales
# 0     29.02
# 1      3.58
# 2     12.88
# 3     11.01
# 4      8.89

# %%
eu_percent= eu_sales.groupby('Year')['Genre'].count().reset_index()
eu_percent['Percent']= 100*eu_percent['Genre']/eu_percent['Genre'].sum()
eu_percent.sort_values(by = 'Genre', ascending= False).head(10)
# Out:
#       Year  Genre   Percent
# 29  2009.0   1431  8.783991
# 28  2008.0   1428  8.765576
# 30  2010.0   1257  7.715917
# 27  2007.0   1201  7.372169
# 31  2011.0   1136  6.973175
# 26  2006.0   1008  6.187465
# 25  2005.0    936  5.745504
# 22  2002.0    829  5.088699
# 23  2003.0    775  4.757228
# 24  2004.0    744  4.566939

# %%
df.groupby('Genre')['EU_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Name')['EU_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Wii Sports                        29.02
# Grand Theft Auto V                23.04
# Mario Kart Wii                    12.88
# FIFA 15                           12.40
# Call of Duty: Modern Warfare 3    11.29
# FIFA 16                           11.29
# FIFA 14                           11.14
# Call of Duty: Black Ops II        11.05
# Wii Sports Resort                 11.01
# Nintendogs                        11.00
# Name: EU_Sales, dtype: float64

# %%
df.groupby('Name')['EU_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
eu_percent= eu_sales.groupby('Year')['Publisher'].count().reset_index()
eu_percent['Percent']= 100*eu_percent['Publisher']/eu_percent['Publisher'].sum()
eu_percent.sort_values(by = 'Publisher', ascending= False).head(10)
# Out:
#       Year  Publisher   Percent
# 29  2009.0       1431  8.783991
# 28  2008.0       1428  8.765576
# 30  2010.0       1257  7.715917
# 27  2007.0       1201  7.372169
# 31  2011.0       1136  6.973175
# 26  2006.0       1008  6.187465
# 25  2005.0        936  5.745504
# 22  2002.0        829  5.088699
# 23  2003.0        775  4.757228
# 24  2004.0        744  4.566939

# %%
df.groupby('Genre')['EU_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Genre
# Action          516.48
# Sports          371.34
# Shooter         310.45
# Racing          236.31
# Misc            211.77
# Platform        200.65
# Role-Playing    187.57
# Simulation      113.02
# Fighting        100.00
# Adventure        63.74
# Name: EU_Sales, dtype: float64

# %%
df.groupby('Genre')['EU_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Platform')['EU_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Platform
# PS3     340.47
# PS2     332.63
# X360    278.00
# Wii     264.35
# PS      212.38
# DS      194.05
# PC      137.35
# PS4     123.70
# GBA      72.49
# PSP      67.16
# Name: EU_Sales, dtype: float64

# %%
df.groupby('Platform')['EU_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Publisher')['EU_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Publisher
# Nintendo                        418.30
# Electronic Arts                 367.38
# Activision                      213.72
# Sony Computer Entertainment     187.55
# Ubisoft                         163.03
# Take-Two Interactive            117.95
# THQ                              94.60
# Sega                             81.41
# Konami Digital Entertainment     68.62
# Microsoft Game Studios           68.61
# Name: EU_Sales, dtype: float64

# %%
df.groupby('Publisher')['EU_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Year')['EU_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Year
# 2009.0    191.59
# 2008.0    184.40
# 2010.0    176.57
# 2011.0    167.31
# 2007.0    160.18
# 2006.0    129.24
# 2013.0    125.80
# 2014.0    125.63
# 2005.0    121.56
# 2012.0    118.76
# Name: EU_Sales, dtype: float64

# %%
df.groupby('Year')['EU_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %% [markdown]
# Japan Game sales

# %%
df.groupby('Name')['JP_Sales'].sum().sort_values(ascending=False).head(10)

# %%
df.groupby('Name')['JP_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Genre')['JP_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Genre
# Role-Playing    350.29
# Action          158.65
# Sports          134.76
# Platform        130.65
# Misc            106.67
# Fighting         87.15
# Simulation       63.54
# Puzzle           56.68
# Racing           56.61
# Adventure        51.99
# Name: JP_Sales, dtype: float64

# %%
df.groupby('Genre')['JP_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Platform')['JP_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Platform
# DS      175.02
# PS      139.78
# PS2     137.54
# SNES    116.55
# NES      98.65
# 3DS      97.30
# GB       85.12
# PS3      79.21
# PSP      75.89
# Wii      68.28
# Name: JP_Sales, dtype: float64

# %%
df.groupby('Platform')['JP_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Publisher')['JP_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Publisher
# Nintendo                        454.99
# Namco Bandai Games              126.84
# Konami Digital Entertainment     90.93
# Sony Computer Entertainment      74.10
# Capcom                           67.38
# Sega                             56.19
# Square Enix                      49.79
# SquareSoft                       40.13
# Enix Corporation                 32.40
# Tecmo Koei                       29.21
# Name: JP_Sales, dtype: float64

# %%
df.groupby('Publisher')['JP_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Year')['JP_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Year
# 2006.0    73.73
# 2009.0    61.89
# 2007.0    60.29
# 2008.0    60.26
# 2010.0    59.49
# 1996.0    57.44
# 2005.0    54.28
# 2011.0    53.04
# 1999.0    52.34
# 2012.0    51.74
# Name: JP_Sales, dtype: float64

# %%
df.groupby('Year')['JP_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %% [markdown]
# Other Sales

# %%
df.groupby('Name')['Other_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# Grand Theft Auto: San Andreas     10.72
# Wii Sports                         8.46
# Grand Theft Auto V                 8.03
# Gran Turismo 4                     7.53
# Call of Duty: Black Ops II         3.88
# FIFA Soccer 08                     3.53
# Pro Evolution Soccer 2008          3.51
# Call of Duty: Black Ops 3          3.42
# Call of Duty: Modern Warfare 3     3.35
# Mario Kart Wii                     3.31
# Name: Other_Sales, dtype: float64

# %%
df.groupby('Name')['Other_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Genre')['Other_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Genre
# Action          184.92
# Sports          132.65
# Shooter         101.90
# Racing           76.68
# Misc             73.92
# Role-Playing     59.38
# Platform         51.51
# Fighting         36.19
# Simulation       31.36
# Adventure        16.70
# Name: Other_Sales, dtype: float64

# %%
df.groupby('Genre')['Other_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Platform')['Other_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Platform
# PS2     190.47
# PS3     140.81
# X360     84.67
# Wii      79.20
# DS       60.29
# PS4      43.36
# PSP      41.52
# PS       40.69
# PC       24.33
# 3DS      12.55
# Name: Other_Sales, dtype: float64

# %%
df.groupby('Platform')['Other_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Publisher')['Other_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Publisher
# Electronic Arts                 127.63
# Nintendo                         95.19
# Sony Computer Entertainment      80.40
# Activision                       74.79
# Take-Two Interactive             55.20
# Ubisoft                          50.16
# THQ                              32.11
# Konami Digital Entertainment     29.91
# Sega                             24.30
# Microsoft Game Studios           18.56
# Name: Other_Sales, dtype: float64

# %%
df.groupby('Publisher')['Other_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Year')['Other_Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Year
# 2008.0    82.39
# 2007.0    77.58
# 2009.0    74.77
# 2010.0    59.90
# 2006.0    54.43
# 2011.0    54.39
# 2004.0    47.24
# 2005.0    40.55
# 2014.0    40.02
# 2013.0    39.82
# Name: Other_Sales, dtype: float64

# %%
df.groupby('Year')['Other_Sales'].sum().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
df.groupby('Genre').sum()
# Out:
#                   Rank       Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        25955792  6527703.0    861.77    516.48    158.65       184.92
# Adventure     14704318  2558355.0    101.93     63.74     51.99        16.70
# Fighting       6371780  1675871.0    220.74    100.00     87.15        36.19
# Misc          14445141  3384308.0    396.92    211.77    106.67        73.92
# Platform       6019939  1753335.0    445.99    200.65    130.65        51.51
# Puzzle         5496785  1142980.0    122.01     50.52     56.68        12.47
# Racing         9699328  2455923.0    356.93    236.31     56.61        76.68
# Role-Playing  11840252  2950365.0    326.50    187.57    350.29        59.38
# Shooter        9399409  2571588.0    575.16    310.45     38.18       101.90
# Simulation     7269349  1701558.0    181.78    113.02     63.54        31.36
# Sports        17105195  4620621.0    670.09    371.34    134.76       132.65
# ...

# %%
y = vg_data.groupby(['Year'])['Global_Sales'].sum()
x = y.index.astype(int)
plt.figure(figsize=(10,6))
ax=sns.barplot(y = y, x = x)
#plt.xlabel(xlabel='Year', fontsize=16)
plt.xticks(fontsize=12, rotation=50)
#plt.ylabel(ylabel='Millions $', fontsize=16)
#plt.title(label='Game Sales in Millions $ Per Year', fontsize=20)
plt.show()

# %%
#fig,ax = plt.subplots(figsize= (10,5))
ax1= na_sales.groupby("Year")["NA_Sales"].size().plot(x="Year",y="Genre")
plt.figure()
#ax2 = vg_data.groupby("Year")["Global_Sales"].size().plot(x="Year",y="Genre")
#plt.figure()

# %%
x= vg_data.groupby(["Year"])["Global_Sales"].sum()

# %%
x.head()
# Out:
# Year
# 1980.0    11.38
# 1981.0    35.77
# 1982.0    28.86
# 1983.0    16.79
# 1984.0    50.36
# Name: Global_Sales, dtype: float64

# %%
na_games= na_sales.groupby(["Year"])["NA_Sales"].sum()

# %%
na_games.head()
# Out:
# Year
# 1980.0    10.59
# 1981.0    33.40
# 1982.0    26.92
# 1983.0     7.76
# 1984.0    33.28
# Name: NA_Sales, dtype: float64

# %%
y= na_sales.groupby(["Year"])["NA_Sales"].sum()
x= y.index.astype(int)
plt.figure(figsize=(10,6))
ax=sns.barplot(y = y, x = x)
#plt.xlabel(xlabel='Year', fontsize=16)
plt.xticks(fontsize=12, rotation=50)
#plt.ylabel(ylabel='Millions $', fontsize=16)
#plt.title(label='Game Sales in Millions $ Per Year', fontsize=20)
plt.show()

# %%
p= vg_data.groupby('Year')['Publisher'].count().reset_index()
p['Percent']= 100*p['Publisher']/p['Publisher'].sum()
p.sort_values(by = 'Publisher', ascending= False).head(10)
# Out:
#       Year  Publisher   Percent
# 29  2009.0       1431  8.783991
# 28  2008.0       1428  8.765576
# 30  2010.0       1257  7.715917
# 27  2007.0       1201  7.372169
# 31  2011.0       1136  6.973175
# 26  2006.0       1008  6.187465
# 25  2005.0        936  5.745504
# 22  2002.0        829  5.088699
# 23  2003.0        775  4.757228
# 24  2004.0        744  4.566939

# %%
y= na_sales.groupby(["Platform"])["NA_Sales"].sum()
x= y.index.astype(str)
plt.figure(figsize=(10,6))
ax=sns.barplot(y = y, x = x, order = na_sales.sort_values("NA_Sales").Platform)
plt.xlabel(xlabel='Publisher', fontsize=20)
plt.xticks(fontsize=12, rotation=90)
#plt.ylabel(ylabel='Millions $', fontsize=16)
#plt.title(label='Game Sales in Millions $ Per Year', fontsize=20)
plt.show()
